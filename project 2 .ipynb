# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("D:\project 2 kgisl\Motor_Vehicle_Collisions_-_Crashes.csv")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09-11-2021      02:39        NaN       NaN        NaN        NaN
# 1        03/26/2022      11:45        NaN       NaN        NaN        NaN
# 2        06/29/2022      06:55        NaN       NaN        NaN        NaN
# 3        09-11-2021      09:35   BROOKLYN   11208.0  40.667202 -73.866500
# 4        12/14/2021      08:13   BROOKLYN   11233.0  40.683304 -73.917274
# ...             ...        ...        ...       ...        ...        ...
# 1048570  09-08-2016      17:10        NaN       NaN  40.742670 -73.828410
# 1048571  08/30/2016      13:58  MANHATTAN   10016.0  40.744778 -73.975890
# 1048572  09/14/2016      08:58      BRONX   10472.0  40.829230 -73.875510
# 1048573  08/24/2016      10:33        NaN       NaN        NaN        NaN
# 1048574  08/25/2016      13:50     QUEENS   11432.0  40.705418 -73.799400
#
#                         LOCATION                    ON STREET NAME  \
# ...

# %%
df_copy=df.copy()

# %%
df_copy
# Out:
#         CRASH DATE          CRASH TIME    BOROUGH ZIP CODE   LATITUDE  \
# 0       2021-09-11 2024-12-17 02:39:00   BROOKLYN  Unknown  40.578950
# 3       2021-09-11 2024-12-17 09:35:00   BROOKLYN  11208.0  40.667202
# 18      2021-12-11 2024-12-17 19:43:00      BRONX  10463.0  40.872620
# 20      2021-12-11 2024-12-17 04:45:00  MANHATTAN  10001.0  40.748917
# 30      2021-12-12 2024-12-17 09:00:00     QUEENS  11385.0  40.704470
# ...            ...                 ...        ...      ...        ...
# 1048558 2016-09-02 2024-12-17 21:09:00   BROOKLYN  11226.0  40.646630
# 1048561 2016-09-05 2024-12-17 16:05:00  MANHATTAN  10032.0  40.842438
# 1048563 2016-09-04 2024-12-17 20:05:00      BRONX  10451.0  40.823860
# 1048568 2016-09-03 2024-12-17 08:47:00   BROOKLYN  11203.0  40.658120
# 1048570 2016-09-08 2024-12-17 17:10:00   BROOKLYN  Unknown  40.742670
#
#          LONGITUDE                 LOCATION                    ON STREET NAME  \
# ...

# %%
df.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  671683.000000  973752.000000  973752.000000               1.048558e+06
# mean    10869.629666      40.578950     -73.664787               3.209904e-01
# std       541.459733       2.437125       4.615499               7.027576e-01
# min     10000.000000       0.000000    -201.359990               0.000000e+00
# 25%     10453.000000      40.667340     -73.970480               0.000000e+00
# 50%     11208.000000      40.719760     -73.922554               0.000000e+00
# 75%     11249.000000      40.774292     -73.863560               0.000000e+00
# max     11697.000000      41.126150       0.000000               4.000000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.048545e+06                   1.048575e+06
# mean               1.476331e-03                   5.419927e-02
# std                4.066263e-02                   2.389923e-01
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   CRASH DATE                     1048575 non-null  object
#  1   CRASH TIME                     1048575 non-null  object
#  2   BOROUGH                        671867 non-null   object
#  3   ZIP CODE                       671683 non-null   float64
#  4   LATITUDE                       973752 non-null   float64
#  5   LONGITUDE                      973752 non-null   float64
#  6   LOCATION                       973752 non-null   object
#  7   ON STREET NAME                 791565 non-null   object
#  8   CROSS STREET NAME              505544 non-null   object
#  9   OFF STREET NAME                255682 non-null   object
#  10  NUMBER OF PERSONS INJURED      1048558 non-null  float64
# ...

# %%
df_copy.head()
# Out:
#    CRASH DATE          CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  2021-09-11 2024-12-17 02:39:00   BROOKLYN  Unknown  40.578950 -73.664787
# 3  2021-09-11 2024-12-17 09:35:00   BROOKLYN  11208.0  40.667202 -73.866500
# 18 2021-12-11 2024-12-17 19:43:00      BRONX  10463.0  40.872620 -73.904686
# 20 2021-12-11 2024-12-17 04:45:00  MANHATTAN  10001.0  40.748917 -73.993546
# 30 2021-12-12 2024-12-17 09:00:00     QUEENS  11385.0  40.704470 -73.901480
#
#                    LOCATION                    ON STREET NAME  \
# 0                (0.0, 0.0)             WHITESTONE EXPRESSWAY
# 3     (40.667202, -73.8665)  BELT PARKWAY
# 18   (40.87262, -73.904686)             WEST KINGSBRIDGE ROAD
# 20  (40.748917, -73.993546)  BELT PARKWAY
# 30    (40.70447, -73.90148)  BELT PARKWAY
#
#    CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0          20 AVENUE  772       EDGEWATER ROAD                  ...
# ...

# %%
df_copy.isnull()
# Out:
#          CRASH DATE  CRASH TIME  BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0             False       False    False     False     False      False
# 3             False       False    False     False     False      False
# 18            False       False    False     False     False      False
# 20            False       False    False     False     False      False
# 30            False       False    False     False     False      False
# ...             ...         ...      ...       ...       ...        ...
# 1048558       False       False    False     False     False      False
# 1048561       False       False    False     False     False      False
# 1048563       False       False    False     False     False      False
# 1048568       False       False    False     False     False      False
# 1048570       False       False    False     False     False      False
#
#          LOCATION  ON STREET NAME  CROSS STREET NAME  OFF STREET NAME  ...  \
# ...

# %%
duplicates=(df_copy.duplicated()).sum()
duplicates
# Out:
# 0

# %%
df_copy.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           376708
# ZIP CODE                          376892
# LATITUDE                           74823
# LONGITUDE                          74823
# LOCATION                           74823
# ON STREET NAME                    257010
# CROSS STREET NAME                 543031
# OFF STREET NAME                   792893
# NUMBER OF PERSONS INJURED             17
# NUMBER OF PERSONS KILLED              30
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       3759
# CONTRIBUTING FACTOR VEHICLE 2     178539
# CONTRIBUTING FACTOR VEHICLE 3     970996
# CONTRIBUTING FACTOR VEHICLE 4    1030532
# CONTRIBUTING FACTOR VEHICLE 5    1043539
# ...

# %%
df_copy['LATITUDE'] = df_copy['LATITUDE'].fillna(df_copy['LATITUDE'].mean())
df_copy['LONGITUDE'] = df_copy['LONGITUDE'].fillna(df_copy['LONGITUDE'].mean())

# %%
df_copy['BOROUGH'] = df_copy['BOROUGH'].fillna(df_copy['BOROUGH'].mode()[0])

# %%
df_copy['LOCATION'] = df_copy['LOCATION'].fillna(df_copy['LOCATION'].mode()[0])

# %%
df_copy['ON STREET NAME'] = df_copy['ON STREET NAME'].fillna(df_copy['ON STREET NAME'].mode()[0])

# %%
df_copy['CROSS STREET NAME'] = df_copy['CROSS STREET NAME'].fillna(df_copy['CROSS STREET NAME'].mode()[0])

# %%
df_copy['OFF STREET NAME'] = df_copy['OFF STREET NAME'].fillna(df_copy['OFF STREET NAME'].mode()[0])

# %%
df_copy['CONTRIBUTING FACTOR VEHICLE 1'] = df_copy['CONTRIBUTING FACTOR VEHICLE 1'].fillna(df_copy['CONTRIBUTING FACTOR VEHICLE 1'].mode()[0])
df_copy['CONTRIBUTING FACTOR VEHICLE 2'] = df_copy['CONTRIBUTING FACTOR VEHICLE 2'].fillna(df_copy['CONTRIBUTING FACTOR VEHICLE 2'].mode()[0])
df_copy['CONTRIBUTING FACTOR VEHICLE 3'] = df_copy['CONTRIBUTING FACTOR VEHICLE 3'].fillna(df_copy['CONTRIBUTING FACTOR VEHICLE 3'].mode()[0])
df_copy['CONTRIBUTING FACTOR VEHICLE 4'] = df_copy['CONTRIBUTING FACTOR VEHICLE 4'].fillna(df_copy['CONTRIBUTING FACTOR VEHICLE 4'].mode()[0])
df_copy['CONTRIBUTING FACTOR VEHICLE 5'] = df_copy['CONTRIBUTING FACTOR VEHICLE 5'].fillna(df_copy['CONTRIBUTING FACTOR VEHICLE 5'].mode()[0])

# %%
df_copy['ZIP CODE'] = df_copy['ZIP CODE'].fillna('Unknown')

# %%
df_copy['VEHICLE TYPE CODE 1'] = df_copy['VEHICLE TYPE CODE 1'].fillna(df_copy['VEHICLE TYPE CODE 1'].mode()[0])
df_copy['VEHICLE TYPE CODE 2'] = df_copy['VEHICLE TYPE CODE 2'].fillna(df_copy['VEHICLE TYPE CODE 2'].mode()[0])
df_copy['VEHICLE TYPE CODE 3'] = df_copy['VEHICLE TYPE CODE 3'].fillna(df_copy['VEHICLE TYPE CODE 3'].mode()[0])
df_copy['VEHICLE TYPE CODE 4'] = df_copy['VEHICLE TYPE CODE 4'].fillna(df_copy['VEHICLE TYPE CODE 4'].mode()[0])
df_copy['VEHICLE TYPE CODE 5'] = df_copy['VEHICLE TYPE CODE 5'].fillna(df_copy['VEHICLE TYPE CODE 5'].mode()[0])

# %%
df_copy.fillna(df_copy.mean(numeric_only=True), inplace=True)

# %%
for col in df_copy.select_dtypes(include='category'):
    df_copy[col].fillna(df_copy[col].mode()[0], inplace=True)

# %%
df_copy['CRASH DATE'] = pd.to_datetime(df_copy['CRASH DATE'], errors='coerce')

# Drop rows where CRASH DATE conversion failed
df_copy = df_copy.dropna(subset=['CRASH DATE'])

# %%
print(df_copy.isnull().sum())
# Out:
# CRASH DATE                       0
# CRASH TIME                       0
# BOROUGH                          0
# ZIP CODE                         0
# LATITUDE                         0
# LONGITUDE                        0
# LOCATION                         0
# ON STREET NAME                   0
# CROSS STREET NAME                0
# OFF STREET NAME                  0
# NUMBER OF PERSONS INJURED        0
# NUMBER OF PERSONS KILLED         0
# NUMBER OF PEDESTRIANS INJURED    0
# NUMBER OF PEDESTRIANS KILLED     0
# NUMBER OF CYCLIST INJURED        0
# NUMBER OF CYCLIST KILLED         0
# NUMBER OF MOTORIST INJURED       0
# NUMBER OF MOTORIST KILLED        0
# CONTRIBUTING FACTOR VEHICLE 1    0
# CONTRIBUTING FACTOR VEHICLE 2    0
# CONTRIBUTING FACTOR VEHICLE 3    0
# CONTRIBUTING FACTOR VEHICLE 4    0
# CONTRIBUTING FACTOR VEHICLE 5    0
# COLLISION_ID                     0
# VEHICLE TYPE CODE 1              0
# VEHICLE TYPE CODE 2              0
# VEHICLE TYPE CODE 3              0
# ...

# %%
df_copy
# Out:
#          CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09-11-2021      02:39        NaN       NaN        NaN        NaN
# 1        03/26/2022      11:45        NaN       NaN        NaN        NaN
# 2        06/29/2022      06:55        NaN       NaN        NaN        NaN
# 3        09-11-2021      09:35   BROOKLYN   11208.0  40.667202 -73.866500
# 4        12/14/2021      08:13   BROOKLYN   11233.0  40.683304 -73.917274
# ...             ...        ...        ...       ...        ...        ...
# 1048570  09-08-2016      17:10        NaN       NaN  40.742670 -73.828410
# 1048571  08/30/2016      13:58  MANHATTAN   10016.0  40.744778 -73.975890
# 1048572  09/14/2016      08:58      BRONX   10472.0  40.829230 -73.875510
# 1048573  08/24/2016      10:33        NaN       NaN        NaN        NaN
# 1048574  08/25/2016      13:50     QUEENS   11432.0  40.705418 -73.799400
#
#                         LOCATION                    ON STREET NAME  \
# ...

# %%
plt.figure(figsize=(5, 3))

# Plotting histogram for CRASH DATE distribution
df_copy['CRASH DATE'] = pd.to_datetime(df_copy['CRASH DATE'], errors='coerce')
df_copy['YEAR'] = df_copy['CRASH DATE'].dt.year  # Extracting the year for histogram

plt.hist(df_copy['YEAR'].dropna(), bins=range(int(df_copy['YEAR'].min()), int(df_copy['YEAR'].max()) + 1), 
         color='c', alpha=0.7, edgecolor='black')

plt.title('Histogram of Crashes by Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Plot histograms for numerical columns
numerical_columns = ['LATITUDE', 'LONGITUDE', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 
                     'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 
                     'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED', 
                     'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED']

plt.figure(figsize=(22, 10))

for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 4, i)
    plt.hist(df_copy[column].dropna(), bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 3))

# Boxplot for LATITUDE
plt.subplot(1, 2, 1)
plt.boxplot(df_copy['LATITUDE'].dropna())
plt.title('Boxplot of LATITUDE')
plt.ylabel('LATITUDE')

# Boxplot for LONGITUDE
plt.subplot(1, 2, 2)
plt.boxplot(df_copy['LONGITUDE'].dropna())
plt.title('Boxplot of LONGITUDE')
plt.ylabel('LONGITUDE')
plt.tight_layout()
plt.show()

# %%
df_copy['CRASH DATE'] = pd.to_datetime(df_copy['CRASH DATE'])
df_copy['CRASH TIME'] = pd.to_datetime(df_copy['CRASH TIME'], errors='coerce')

# Extract month, day of the week, and hour for analysis
df_copy['Month'] = df_copy['CRASH DATE'].dt.month
df_copy['Day of Week'] = df_copy['CRASH DATE'].dt.dayofweek
df_copy['Hour'] = df_copy['CRASH TIME'].dt.hour

# Crash frequency by month
plt.figure(figsize=(5, 3))
df_copy['Month'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Bar Plot for Crash Frequency by Month')
plt.xlabel('Month')
plt.ylabel('Number of Crashes')
plt.show()

# Crash frequency by hour
plt.figure(figsize=(5, 3))
df_copy['Hour'].value_counts().sort_index().plot(kind='bar', color='lightcoral')
plt.title('Bar Plot For Crash Frequency by Hour of the Day')
plt.xlabel('Hour')
plt.ylabel('Number of Crashes')
plt.show()

# %%
import seaborn as sns

# Correlation heatmap for numerical columns
correlation_matrix = df_copy[numerical_columns].corr()
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.scatter(df_copy['NUMBER OF PERSONS INJURED'], df_copy['NUMBER OF PERSONS KILLED'], alpha=1, color='g')
plt.title('Scatter plot for Number of Injuries vs Number of Deaths')
plt.xlabel('Number of Persons Injured')
plt.ylabel('Number of Persons Killed')
plt.grid(True)
plt.show()

# %%
 #Convert CRASH DATE to datetime
df_copy['CRASH DATE'] = pd.to_datetime(df_copy['CRASH DATE'], errors='coerce')

# Group by CRASH DATE and count crashes
crash_counts = df_copy.groupby('CRASH DATE').size()

# Line plot for crashes over time
plt.figure(figsize=(5, 3))
plt.plot(crash_counts.index, crash_counts.values, color='b', lw=2)
plt.title('Line Plot For Number of Crashes Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Crashes')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# KDE Plot for Number of Persons Injured
plt.figure(figsize=(8, 6))
sns.kdeplot(df_copy['NUMBER OF PERSONS INJURED'], shade=True, color='blue', label='Injuries')
sns.kdeplot(df_copy['NUMBER OF PERSONS KILLED'], shade=True, color='red', label='Fatalities')
plt.title('KDE Plot: Injuries and Fatalities')
plt.xlabel('Count')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
heatmap_data = df_copy.groupby(['YEAR', 'MONTH']).size().unstack()

# Heatmap visualization
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=True, linewidths=0.5)
plt.title('Heatmap of Crashes by Year and Month')
plt.xlabel('Month')
plt.ylabel('Year')
plt.show()

# %%
# Contribution Factors Bar Chart
factor_counts = df_copy['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)
plt.figure(figsize=(8, 5))
factor_counts.plot(kind='bar', color='purple', alpha=0.6)
plt.title('Top 10 Contributing Factors to Crashes')
plt.xlabel('Contributing Factor')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
from scipy.stats import f_oneway

# Remove rows with missing values in BOROUGH and NUMBER OF PERSONS INJURED
df_anova = df_copy.dropna(subset=['BOROUGH', 'NUMBER OF PERSONS INJURED'])

# Group data by Borough
borough_groups = [group['NUMBER OF PERSONS INJURED'].values 
                  for name, group in df_anova.groupby('BOROUGH')]

# Perform ANOVA Test
f_stat, p_value = f_oneway(*borough_groups)

# Output results
print("ANOVA Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Result: Reject the Null Hypothesis (Significant differences exist).")
else:
    print("Result: Fail to Reject the Null Hypothesis (No significant differences).")
# Out:
# ANOVA Results:
# F-statistic: 528.4990
# P-value: 0.0000
# Result: Reject the Null Hypothesis (Significant differences exist).
